# %%
# !pip install diffusers["torch"]
# Out:
# Collecting diffusers[torch]
#   Downloading diffusers-0.33.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: importlib-metadata in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from diffusers[torch]) (8.6.1)
# Requirement already satisfied: filelock in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from diffusers[torch]) (3.18.0)
# Requirement already satisfied: huggingface-hub>=0.27.0 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from diffusers[torch]) (0.29.3)
# Requirement already satisfied: numpy in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from diffusers[torch]) (2.2.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from diffusers[torch]) (2024.11.6)
# Requirement already satisfied: requests in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from diffusers[torch]) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from diffusers[torch]) (0.5.3)
# Requirement already satisfied: Pillow in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from diffusers[torch]) (11.1.0)
# Requirement already satisfied: torch>=1.4 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from diffusers[torch]) (2.6.0)
# Collecting accelerate>=0.31.0 (from diffusers[torch])
#   Using cached accelerate-1.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: packaging>=20.0 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from accelerate>=0.31.0->diffusers[torch]) (24.2)
# Requirement already satisfied: psutil in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from accelerate>=0.31.0->diffusers[torch]) (5.9.0)
# Requirement already satisfied: pyyaml in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from accelerate>=0.31.0->diffusers[torch]) (6.0.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from huggingface-hub>=0.27.0->diffusers[torch]) (2024.12.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from huggingface-hub>=0.27.0->diffusers[torch]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from huggingface-hub>=0.27.0->diffusers[torch]) (4.13.0)
# Requirement already satisfied: networkx in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (3.4.2)
# Requirement already satisfied: jinja2 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (3.2.0)
# Requirement already satisfied: setuptools in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from torch>=1.4->diffusers[torch]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from sympy==1.13.1->torch>=1.4->diffusers[torch]) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from importlib-metadata->diffusers[torch]) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from requests->diffusers[torch]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from requests->diffusers[torch]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from requests->diffusers[torch]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from requests->diffusers[torch]) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/rtxmsi1/anaconda3/envs/diffusion-env/lib/python3.13/site-packages (from jinja2->torch>=1.4->diffusers[torch]) (3.0.2)
# Using cached accelerate-1.6.0-py3-none-any.whl (354 kB)
# Downloading diffusers-0.33.1-py3-none-any.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 288.9 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: diffusers, accelerate
# Successfully installed accelerate-1.6.0 diffusers-0.33.1

# %%
from PIL import Image
import torch
from transformers import CLIPTextModel, CLIPTokenizer
from diffusers import AutoencoderKL, UNet2DConditionModel, PNDMScheduler

vae = AutoencoderKL.from_pretrained("CompVis/stable-diffusion-v1-4", subfolder="vae", use_safetensors=True)
tokenizer = CLIPTokenizer.from_pretrained("CompVis/stable-diffusion-v1-4", subfolder="tokenizer")
text_encoder = CLIPTextModel.from_pretrained(
    "CompVis/stable-diffusion-v1-4", subfolder="text_encoder", use_safetensors=True
)
unet = UNet2DConditionModel.from_pretrained(
    "CompVis/stable-diffusion-v1-4", subfolder="unet", use_safetensors=True
)
# Out:
# config.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]

# %%
from dataset import PineappleDataset

import matplotlib.pyplot as plt
import numpy as np

trainset = PineappleDataset(train=True, train_ratio=0.8)

vae.eval()
vae.cuda()  # Move model to GPU if available

test_set = PineappleDataset(train=False, train_ratio=0.8)
# 2. Load the test image
test_image = test_set[0]['image']
test_image = torch.tensor(test_image).unsqueeze(0).cuda()  # Add batch dimension and move to GPU
# 3. Pass the image through the model
with torch.no_grad():
    reconstructed_image = vae(test_image)
    reconstructed_image = reconstructed_image.sample.squeeze(0).cpu().numpy()  # Remove batch dimension and move to CPU
    reconstructed_image = np.transpose(reconstructed_image, (1, 2, 0))  # Change to HWC format
    reconstructed_image = (reconstructed_image * 255).astype(np.uint8)  # Convert to uint8

# 4. Display the original and reconstructed images
fig = plt.figure(figsize=(12, 6))
columns = 2
rows = 1
original_image = test_set[0]['image'].transpose((1, 2, 0))
original_image = (original_image * 255).astype(np.uint8)  # Convert to uint8
# add labels to the images
fig.add_subplot(rows, columns, 1, title='Original Image')
plt.imshow(original_image)
fig.add_subplot(rows, columns, 2, title='Reconstructed Image')
plt.imshow(reconstructed_image)
plt.show()

# %%
reconstructed_image.shape
# Out:
# (1, 3, 256, 256)

# %%
import matplotlib.pyplot as plt
import torch

# Your code
batch_size = 8
height, width = 128, 128
latent = torch.randn(batch_size, 4, height // 8, width // 8).cuda()

decoder = vae.decoder
reconstructed_image = decoder(latent)

# Move tensor to CPU and clamp values (for visualization)
reconstructed_image = reconstructed_image.detach().cpu().clamp(0, 1)

# Plot the images
n_images = min(batch_size, 8)  # Plot up to 8 images
fig, axes = plt.subplots(1, n_images, figsize=(15, 3))
for i in range(n_images):
    img = reconstructed_image[i].permute(1, 2, 0)  # CHW -> HWC
    axes[i].imshow(img)
    axes[i].axis("off")
plt.tight_layout()
plt.show()
